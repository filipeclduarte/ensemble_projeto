# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dados/df.csv', index_col = 0)

# %%
plt.figure(figsize=(9,6))
df['value'][:5000].plot(label='train')
df['value'][5000:6000].plot(label='test')
plt.ylabel('Consumption (MW)')
plt.xlabel('Time(h)')
plt.grid()
plt.legend()
plt.show()
